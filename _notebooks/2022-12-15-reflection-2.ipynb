// %% [markdown]
// # Final Reflection 2
// > Units 6-10 and HW
// - badges: true
// - comments: true
// - categories: [jupyter, mc]

// %% [markdown]
// Unit | Score
// -- | --
// 6 | 0.9
// 7 | 0.95
// 8 | 0.95
// 9 | 1
// 10 | 1
// TOTAL | 4.8

// %% [markdown]
// # Unit 6: Arrays
//
// [See Jupyter Notebook here](https://xu-ellen.github.io/ap-csa-fastpages/jupyter/cb/2022/10/25/array.html)
//
// Takeaways:
// - Arrays are a collection of data of the same type
// - Arrays are indexed starting at 0
// - Arrays are immutable
// - Need to import java.util.Arrays to use Arrays.toString()
// - Access elements through array[index]
//
// Examples:
// ```java
// int[] arr = {1, 2, 3, 4, 5};
// System.out.println(Arrays.toString(arr));
// ```
//
// # Unit 7: ArrayList
//
// [See Jupyter Notebook here](https://xu-ellen.github.io/ap-csa-fastpages/jupyter/cb/2022/11/30/arrayList.html)
//
// Takeaways:
// - ArrayList is a resizable array
// - Primitive data types: int, double, boolean, char
// - Wrapper classes: Integer, Double, Boolean, Character
// - ArrayLists are mutable
// - Need to import java.util.ArrayList to use ArrayList methods
//
// Examples:
// ```java
// ArrayList<Integer> arr = new ArrayList<Integer>();
// arr.add(1);
// arr.add(2);
// System.out.println(arr);
// ```
//
// # Unit 8: 2D Arrays
//
// [See Jupyter Notebook here](https://xu-ellen.github.io/ap-csa-fastpages/jupyter/cb/2022/12/07/d-array.html)
//
// Takeaways:
// - 2D Arrays are arrays of arrays
// - 2D Arrays are indexed starting at [0][0]
// Array = a data structure used to implement a collection (list) of primitive or object reference data
// Element = a single value in the array
// Index = the position of the element in the array (starts from 0)
// Array Length = the number of elements in the array
// Is public, so can be accessed in any class
// Is also final, so can’t change it after array has been created
//
// # Unit 9: Inheritance
//
// [See Jupyter Notebook here](https://xu-ellen.github.io/ap-csa-fastpages/jupyter/cb/2022/12/13/inheritance.html)
//
// Takeaways:
// - Inheritance is a way to reuse code
// - Subclass inherits all the methods and variables from the superclass
// - Subclass can override methods from the superclass
// - Subclass can add new methods and variables
// - PolyMorphism: the ability to call the same method on different objects and have different behaviors
// - Superclass: the class being inherited from
//
// # Unit 10: Recursion
//
// [Our group presentation](https://www.canva.com/design/DAFUHTwLygQ/mUJNpi5BWK6fciLq32PFsQ/view?utm_content=DAFUHTwLygQ&utm_campaign=designshare&utm_medium=link2&utm_source=sharebutton)
//
// Takeaways:
// - Recursion is a method that calls itself
// - Base case is the condition that stops the recursion
// - Recursive case is the condition that calls the method again
// - Recursive methods must have a base case
